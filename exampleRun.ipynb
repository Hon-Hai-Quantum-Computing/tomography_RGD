# %% [markdown]
# # overview
# This jupyternote shows how to have basic setting for performing the Quantum State Tomography (QST) by using one of the following optimization approach:
#
# 1. Riemannian Gradient Descent (RGD)
# 2. Momentum-Inspired Factored Gradient Descent (MiFGD)

# %%
import Get_param

from Utility import State_Naming
from Utility import Params_define

from Input_Utility import Gen_Projectors
from Input_measurements import Get_measurement_by_labels

#from main_QST import Default_Setting_Run_Tomography
from main_QST import Default_OptMethod_params, Tomography_over_measurement
from main_QST import Tune_Kappa_Tomography

# %%
#Nk = 6                      #  number of qubits
#m = int(0.3* (4**Nk))       #  number of sampled Pauli matrices
#mea = 8600                  #  mea =  number of shots

Nk = 3                      #  number of qubits
m = 20                      #  number of sampled Pauli matrices
mea = 2400                  #  mea =  number of shots

State_version = { 'StateName': 'GHZ',        #  = 'GHZ', 'Had', 'rand', 'KapRnd'
                      'Nr': 1,                    #  rank: 'GHZ', 'Had' --> only allow Nr =1 
                      'Generate New rand': 1,     #  (only for 'rand', 'KapRnd') 1: generate new data |  0: load existing data
                      'rand matrix version': 1,   #  (only for 'rand', 'KapRnd') version for random matrices  
                      'List_alpha': [5, 7, 10]    #  only for 'KapRnd' to tune Kappa (not needed for other states)
    }

Version_Def = { 
        'Gen New Proj sampling': 1,     #  -1: specify fixed list, 1: generate sampling, 0: load existing sampling
        'Proj version': 1,              #  counting projector version number
        'Gen New Measure': 1,           #  1: generate new shot/calculated measure, 0: load existing 
        'measure version': 2,           #  counting measure version number
    }

# %%
Pj_method = 1               #   the method to save | load  projectors
mea_method = 1              #   the method to save | load  measurement_dict (count_dict) 

measure_method = 3          #  = 1: direct label_list,  = 3: parallel cpu

DirStore = './DataTest'

# %% [markdown]
# ## Define params_setup
# - store all parameters in the dictionary params_setup

# %%
params_setup = Params_define(State_version, Nk, m, mea,\
                Pj_method, mea_method, measure_method, DirStore) 

params_setup = State_Naming(params_setup, \
                State_version, Version_Def)

# %%
params_setup
# Out:
# {'n': 3,
#  'Name': 'GHZ-3',
#  'StateName': 'GHZ',
#  'num_labels': 20,
#  'num_shots': 2400,
#  'Nr': 1,
#  'Noise': -1,
#  'Dir0': './DataTest/GHZ-3',
#  'Pj_method': 1,
#  'mea_method': 1,
#  'measure_method': 3,
#  'Gen New Proj sampling': 1,
#  'Proj version': 1,
#  'Gen New Measure': 1,
#  'measure version': 2,
#  'Data_In': [],
#  'DirRho': './DataTest/GHZ-3/GHZ-3_m20_s1',
#  'Dir2p': './DataTest/GHZ-3',
#  'projector_store_path': './DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_Proj',
#  'Dir2m': './DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1',
#  'measurement_store_path': './DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure'}

# %% [markdown]
# ## generate the projectors = Pauli matrices

# %%
label_list, T_rec, Ncpu_Pj, saveP_bulk  = Gen_Projectors(params_setup)  # creating projectors
# Out:
#  -------------     Generate new labels    ------------
#       Partion_Pj = 0  -->  No partion in Pj
#
#   ***  Pj_file    = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_Proj/Pj_list.pickle  is saved (i.e. dump)
#   ***  label_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_Proj/labels.pickle   is saved
#
#      pool.map  COMPLETED by #CPU = 16
#
#      [projectors] num_cpus = 16,  saved bulk Pj = 1
#
#
#  *****        num_cpus = 16, saved # bulk Pj = 1        ****
#
#  *****   The running time for projector = 1.4340870380401611  ****
#
#     label_list[:10]   = ['ZZX', 'XXZ', 'IYX', 'YZY', 'XYY', 'IXX', 'XXI', 'YYY', 'ZYZ', 'IYI']
#
#     num of projectors = len(label_list) = 20
#     num of saved bulk Proj              = 1
#
#
#   <<<<<<<<                Do_projector time    =  1.4351449012756348           >>>>>>
#
#   ######       saveP_bulk = 1  for Ncpu_Pj = 16    ########

# %% [markdown]
# ## Generate the state and do measurements

# %%
target_density_matrix, input_S, T_rec, Ncpu_meas = \
        Get_measurement_by_labels(params_setup, label_list, T_rec)
# Out:
#   ********   starting to DO measurement (qiskit or qutip)  **************
#
#  num_cpus = 16,  labels size =20
#        saving 0-th label_part DONE
#        saving 1-th label_part DONE
#        saving 2-th label_part DONE
#        saving 3-th label_part DONE
#        saving 4-th label_part DONE
#        saving 5-th label_part DONE
#        saving 6-th label_part DONE
#        saving 7-th label_part DONE
#        saving 8-th label_part DONE
#        saving 9-th label_part DONE
#        saving 10-th label_part DONE
#        saving 11-th label_part DONE
#        saving 12-th label_part DONE
#        saving 13-th label_part DONE
#        saving 14-th label_part DONE
#        saving 15-th label_part DONE
#
#  *****************   saving label_part files DONE  ***********
#
#
#   ml_lab_files = ['ml_labels_10', 'ml_labels_11', 'ml_labels_4', 'ml_labels_3', 'ml_labels_2', 'ml_labels_5', 'ml_labels_13', 'ml_labels_14', 'ml_labels_15', 'ml_labels_12', 'ml_labels_9', 'ml_labels_0', 'ml_labels_7', 'ml_labels_6', 'ml_labels_1', 'ml_labels_8']
#
#     Run_method = 0
#
#   file = ml_labels_10
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_10  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_10.txt
#   file = ml_labels_11
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_11  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_11.txt
#   file = ml_labels_4
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_4  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_4.txt
#   file = ml_labels_3
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_3  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_3.txt
#   file = ml_labels_2
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_2  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_2.txt
#   file = ml_labels_5
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_5  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_5.txt
#   file = ml_labels_13
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_13  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_13.txt
#   file = ml_labels_14
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_14  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_14.txt
#   file = ml_labels_15
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_15  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_15.txt
#   file = ml_labels_12
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_12  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_12.txt
#   file = ml_labels_9
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_9  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_9.txt
#   file = ml_labels_0
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_0  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_0.txt
#   file = ml_labels_7
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_7  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_7.txt
#   file = ml_labels_6
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_6  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_6.txt
#   file = ml_labels_1
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_1  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_1.txt
#   file = ml_labels_8
#
# cmd = python parallel_measurements.py 3 2400 GHZ ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure ml_labels_8  > ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/Rec_qiskit_meas_dict_8.txt
#   ---------- qiskit measurement_dict DONE time = 14.20166802406311 by  sequential qiskit measure each label part
#
#   ---------- DONE of measurement_dict for ALL label_part  ----------
#
#    #####   start loading each data_dict from each label_part   ####
#
#           num_split  = 16
#
#  +++++++++++        start loading   0-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_0.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    1-th   label_list
#       start to calc    0-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.45595812797546387   *****
#
#  ===========        Done calc  0-th  measurement_list    ===========
#
#  +++++++++++        start loading   1-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_1.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    1-th   label_list
#       start to calc    0-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4448819160461426   *****
#
#  ===========        Done calc  1-th  measurement_list    ===========
#
#  +++++++++++        start loading   2-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_2.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4395918846130371   *****
#
#  ===========        Done calc  2-th  measurement_list    ===========
#
#  +++++++++++        start loading   3-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_3.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    1-th   label_list
#       start to calc    0-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4237370491027832   *****
#
#  ===========        Done calc  3-th  measurement_list    ===========
#
#  +++++++++++        start loading   4-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_4.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4261481761932373   *****
#
#  ===========        Done calc  4-th  measurement_list    ===========
#
#  +++++++++++        start loading   5-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_5.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4667079448699951   *****
#
#  ===========        Done calc  5-th  measurement_list    ===========
#
#  +++++++++++        start loading   6-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_6.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.44828295707702637   *****
#
#  ===========        Done calc  6-th  measurement_list    ===========
#
#  +++++++++++        start loading   7-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_7.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.45981812477111816   *****
#
#  ===========        Done calc  7-th  measurement_list    ===========
#
#  +++++++++++        start loading   8-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_8.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4726870059967041   *****
#
#  ===========        Done calc  8-th  measurement_list    ===========
#
#  +++++++++++        start loading   9-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_9.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4396998882293701   *****
#
#  ===========        Done calc  9-th  measurement_list    ===========
#
#  +++++++++++        start loading   10-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_10.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4494199752807617   *****
#
#  ===========        Done calc  10-th  measurement_list    ===========
#
#  +++++++++++        start loading   11-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_11.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    1-th   label_list
#       start to calc    0-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4265317916870117   *****
#
#  ===========        Done calc  11-th  measurement_list    ===========
#
#  +++++++++++        start loading   12-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_12.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.44101786613464355   *****
#
#  ===========        Done calc  12-th  measurement_list    ===========
#
#  +++++++++++        start loading   13-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_13.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    1-th   label_list
#       start to calc    0-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.487410306930542   *****
#
#  ===========        Done calc  13-th  measurement_list    ===========
#
#  +++++++++++        start loading   14-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_14.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#       start to calc    2-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.4126291275024414   *****
#
#  ===========        Done calc  14-th  measurement_list    ===========
#
#  +++++++++++        start loading   15-th data_dict  (to calc measurement_list)    ++++++++++++
#     label_count_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/labs_data_15.pickle
#
#  path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
# Rec_qiskit_meas_dict_0.txt
# Rec_qiskit_meas_dict_1.txt
# Rec_qiskit_meas_dict_10.txt
# Rec_qiskit_meas_dict_11.txt
# Rec_qiskit_meas_dict_12.txt
# Rec_qiskit_meas_dict_13.txt
# Rec_qiskit_meas_dict_14.txt
# Rec_qiskit_meas_dict_15.txt
# Rec_qiskit_meas_dict_2.txt
# Rec_qiskit_meas_dict_3.txt
# Rec_qiskit_meas_dict_4.txt
# Rec_qiskit_meas_dict_5.txt
# Rec_qiskit_meas_dict_6.txt
# Rec_qiskit_meas_dict_7.txt
# Rec_qiskit_meas_dict_8.txt
# Rec_qiskit_meas_dict_9.txt
# labs_data_0.pickle
# labs_data_1.pickle
# labs_data_10.pickle
# labs_data_11.pickle
# labs_data_12.pickle
# labs_data_13.pickle
# labs_data_14.pickle
# labs_data_15.pickle
# labs_data_2.pickle
# labs_data_3.pickle
# labs_data_4.pickle
# labs_data_5.pickle
# labs_data_6.pickle
# labs_data_7.pickle
# labs_data_8.pickle
# labs_data_9.pickle
# ml_labels_0
# ml_labels_1
# ml_labels_10
# ml_labels_11
# ml_labels_12
# ml_labels_13
# ml_labels_14
# ml_labels_15
# ml_labels_2
# ml_labels_3
# ml_labels_4
# ml_labels_5
# ml_labels_6
# ml_labels_7
# ml_labels_8
# ml_labels_9
#     -------------------         start calc measurment_list        ------------------
#
#        ****  use parallel #CPU = 3 to calc measurement_list
#
#        **************  0-th label_part to be parallelly calc   *******
#        **************  1-th label_part to be parallelly calc   *******
#        **************  2-th label_part to be parallelly calc   *******
#       start to calc    2-th   label_list
#       start to calc    0-th   label_list
#       start to calc    1-th   label_list
#     -------------         DONE of calculating measurment_list       ------------------
#
#     ******   cls.calc_measurement_list   -->  time = 0.46659111976623535   *****
#
#  ===========        Done calc  15-th  measurement_list    ===========
#
#     >>>>>>>>        measurement_list is combined and sorted         <<<<<
#
#
#
#           path = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure
#
#           Name = ALL
#
#           ***  measurement_list --> ml_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/measureL_ALL.pickle is saved
#
#
#   <<<<<<<<               Do_measure time             = 21.41615319252014           >>>>>>
#
#   target_density_matrix is created for returning

# %% [markdown]
# ## Do the tomography
# - pm_MiFGD: parameters for running MiFGD
# - pm_RGD: parameters for running RGD

# %%
pm_MiFGD, pm_RGD = Default_OptMethod_params()

Ttot, Wk_dict, params_setup, T_rec = \
        Tomography_over_measurement(params_setup, target_density_matrix, \
                             input_S, pm_RGD, pm_MiFGD, T_rec)
# Out:
#  *********************************************************
#
#    there exists pure state
#
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  ++           start calculating  RGD                 ++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#   self.Noise = shot
#   Pj_method  = 1
#   mea_method = 1
#   --> loading measurement_list DONE from  ml_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/measureL_ALL.pickle
#
# Loading projectors
#    20 projectors loaded
#    Projectors ready to compute with
#
#
#   ******  projectors  -->  time = 0.00027179718017578125   ******
#
#    ===>  to GET measurment_list
#
# Loading measurements
#    Measurements ready to compute with
#
#    **** Loading measurements   -->   time = 5.9604644775390625e-06  ****
#
#   self.coef = 0.6324555320336759
#   InitX     = 1
#  *********   using randomized-SVD  to construct  X0 = uk @ sDiag @ vkh  **************************
#   ***   0-th (A A*) done:   Time --> ATQ: 9.298324584960938e-05,  AG: 9.393692016601562e-05   ***
#   ***   1-th (A A*) done:   Time --> ATQ: 7.605552673339844e-05,  AG: 7.510185241699219e-05   ***
#   ***   2-th (A A*) done:   Time --> ATQ: 7.772445678710938e-05,  AG: 7.700920104980469e-05   ***
#   ***   3-th (A A*) done:   Time --> ATQ: 7.414817810058594e-05,  AG: 8.702278137207031e-05   ***
#   ***   4-th (A A*) done:   Time --> ATQ: 8.273124694824219e-05,  AG: 7.319450378417969e-05   ***
#   ***   5-th (A A*) done:   Time --> ATQ: 7.295608520507812e-05,  AG: 7.605552673339844e-05   ***
#   ***   6-th (A A*) done:   Time --> ATQ: 7.700920104980469e-05,  AG: 7.295608520507812e-05   ***
#   ***   7-th (A A*) done:   Time --> ATQ: 7.295608520507812e-05,  AG: 7.295608520507812e-05   ***
#   ***   8-th (A A*) done:   Time --> ATQ: 7.295608520507812e-05,  AG: 0.0001308917999267578   ***
#   ***   9-th (A A*) done:   Time --> ATQ: 8.821487426757812e-05,  AG: 7.772445678710938e-05   ***
#   ***   10-th (A A*) done:   Time --> ATQ: 7.867813110351562e-05,  AG: 7.605552673339844e-05   ***
#   ***   11-th (A A*) done:   Time --> ATQ: 7.510185241699219e-05,  AG: 7.295608520507812e-05   ***
#   ***   12-th (A A*) done:   Time --> ATQ: 7.390975952148438e-05,  AG: 7.414817810058594e-05   ***
#   ***   13-th (A A*) done:   Time --> ATQ: 7.414817810058594e-05,  AG: 7.390975952148438e-05   ***
#   ***   14-th (A A*) done:   Time --> ATQ: 7.605552673339844e-05,  AG: 7.390975952148438e-05   ***
#    self.rSVD           -->   time = 0.0039899349212646484
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#  --------  X0  --> (-1)-th iteration  [ InitX = 1, SVD choice = -1 ]
#
#       X0 step (RGD)        -->  time = 0.004161834716796875
#
#       X0                   -->  Tr(X0)     = (-0.8276982896113203+6.953293464010551e-18j)
#
#       X0                   -->  Target Err = 1.2981674857846293
#
#     RGD max num_iterations = 150
#
#  --------  0-th iteration
#
#  0-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00017881393432617188
#        [calc_n1_n2] AptGk     -->  time = 3.886222839355469e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.05418731565583237
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [0.51886009 0.00070738]
#         max(s2r)  = 0.5188600903782347
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.9901841414987462e-16
#    ****  0-th iteratation
#
#             min(uk +/- uk_old)   = 0.03690459818239947
#
#          relative_errU = 0.03690459818239947,  relative_errX = 0.3754093367873217
#          Target_Error = 1.1267834820391585
#
#      convergence check   -->  time = 0.00023126602172851562
#
#       stepRGD            -->  time = 0.0007662773132324219
#
#  --------  1-th iteration
#
#  1-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0001628398895263672
#        [calc_n1_n2] AptGk     -->  time = 3.814697265625e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.9325647994809984
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [0.69753765 0.1558477 ]
#         max(s2r)  = 0.6975376508381708
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.3016357472062382e-15
#             min(uk +/- uk_old)   = 1.9514554080515276
#
#          relative_errU = 1.9514554080515272,  relative_errX = 0.7807762280126123
#          Target_Error = 1.2207970682245486
#
#      convergence check   -->  time = 9.703636169433594e-05
#
#       stepRGD            -->  time = 0.0005261898040771484
#
#  --------  2-th iteration
#
#  2-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0002570152282714844
#        [calc_n1_n2] AptGk     -->  time = 4.291534423828125e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.8103551149473213
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [0.84882128 0.09670402]
#         max(s2r)  = 0.848821283033594
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.0303093780778995e-15
#             min(uk +/- uk_old)   = 1.9735669621905445
#
#          relative_errU = 1.9735669621905447,  relative_errX = 0.5440150119190315
#          Target_Error = 1.3129559334197842
#
#      convergence check   -->  time = 9.298324584960938e-05
#
#       stepRGD            -->  time = 0.0006699562072753906
#
#  --------  3-th iteration
#
#  3-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0009870529174804688
#        [calc_n1_n2] AptGk     -->  time = 0.00012302398681640625
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.2364204183919449
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [0.94464158 0.00739627]
#         max(s2r)  = 0.9446415846389514
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.0252531275855447e-15
#             min(uk +/- uk_old)   = 0.08822716635561363
#
#          relative_errU = 0.08822716635561366,  relative_errX = 0.1733063485779757
#          Target_Error = 1.3756500722267724
#
#      convergence check   -->  time = 0.00037670135498046875
#
#       stepRGD            -->  time = 0.002218961715698242
#
#  --------  4-th iteration
#
#  4-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0005300045013427734
#        [calc_n1_n2] AptGk     -->  time = 9.489059448242188e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.08010958686383454
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [9.82574158e-01 8.16420045e-04]
#         max(s2r)  = 0.9825741584606742
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.0204303298852135e-15
#             min(uk +/- uk_old)   = 0.028816344756109374
#
#          relative_errU = 0.028816344756109384,  relative_errX = 0.057788921309015785
#          Target_Error = 1.4020272317001337
#
#      convergence check   -->  time = 0.00022721290588378906
#
#       stepRGD            -->  time = 0.0014469623565673828
#
#  --------  5-th iteration
#
#  5-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0008351802825927734
#        [calc_n1_n2] AptGk     -->  time = 6.008148193359375e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.028119727765135397
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [9.94792395e-01 9.93572998e-05]
#         max(s2r)  = 0.9947923946957999
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.1788483018709705e-15
#             min(uk +/- uk_old)   = 1.9999750323589056
#
#          relative_errU = 1.9999750323589063,  relative_errX = 0.018890366592613873
#          Target_Error = 1.410554489650748
#
#      convergence check   -->  time = 0.00012803077697753906
#
#       stepRGD            -->  time = 0.0013818740844726562
#
#  --------  6-th iteration
#
#  6-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00018930435180664062
#        [calc_n1_n2] AptGk     -->  time = 4.38690185546875e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.009593015060183202
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [9.99284383e-01 1.15114801e-05]
#         max(s2r)  = 0.9992843828721252
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.2580568561600012e-15
#             min(uk +/- uk_old)   = 0.0033940571945641064
#
#          relative_errU = 0.0033940571945641094,  relative_errX = 0.00659795302991442
#          Target_Error = 1.4137425303083737
#
#      convergence check   -->  time = 9.274482727050781e-05
#
#       stepRGD            -->  time = 0.0006017684936523438
#
#  --------  7-th iteration
#
#  7-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0001590251922607422
#        [calc_n1_n2] AptGk     -->  time = 4.506111145019531e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.004008765440928426
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00076588e+00 2.00723774e-06]
#         max(s2r)  = 1.0007658811355034
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.1822657919507806e-15
#             min(uk +/- uk_old)   = 0.0014162268862641452
#
#          relative_errU = 0.0014162268862641467,  relative_errX = 0.002493055176252538
#          Target_Error = 1.4147832005940144
#
#      convergence check   -->  time = 8.988380432128906e-05
#
#       stepRGD            -->  time = 0.0005307197570800781
#
#  --------  8-th iteration
#
#  8-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00016689300537109375
#        [calc_n1_n2] AptGk     -->  time = 3.719329833984375e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.003044771980890884
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00138491e+00 1.15722690e-06]
#         max(s2r)  = 1.001384911432516
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.2754937034009684e-15
#             min(uk +/- uk_old)   = 0.0010750002108383821
#
#          relative_errU = 0.001075000210838383,  relative_errX = 0.0016417344764286935
#          Target_Error = 1.4152253242255186
#
#      convergence check   -->  time = 8.130073547363281e-05
#
#       stepRGD            -->  time = 0.0005092620849609375
#
#  --------  9-th iteration
#
#  9-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0001590251922607422
#        [calc_n1_n2] AptGk     -->  time = 3.790855407714844e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.0029369112542964567
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00139012e+00 1.07668424e-06]
#         max(s2r)  = 1.0013901209753209
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.2082626992492014e-15
#             min(uk +/- uk_old)   = 0.0010369130785476141
#
#          relative_errU = 0.0010369130785476152,  relative_errX = 0.0014664293839865604
#          Target_Error = 1.41522496763179
#
#      convergence check   -->  time = 7.796287536621094e-05
#
#       stepRGD            -->  time = 0.0005321502685546875
#
#  --------  10-th iteration
#
#  10-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0001590251922607422
#        [calc_n1_n2] AptGk     -->  time = 4.38690185546875e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.0029156329350449317
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00137063e+00 1.06115997e-06]
#         max(s2r)  = 1.001370629661492
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.2130479431666983e-15
#             min(uk +/- uk_old)   = 0.0010294205459338154
#
#          relative_errU = 0.0010294205459338162,  relative_errX = 0.0014559362498980514
#          Target_Error = 1.4152152072095634
#
#      convergence check   -->  time = 8.392333984375e-05
#
#       stepRGD            -->  time = 0.0004999637603759766
#
#  --------  11-th iteration
#
#  11-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00022339820861816406
#        [calc_n1_n2] AptGk     -->  time = 6.508827209472656e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.0028809344720913273
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00135915e+00 1.03606476e-06]
#         max(s2r)  = 1.0013591537843527
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.239827788336474e-15
#             min(uk +/- uk_old)   = 0.0010171812497404694
#
#          relative_errU = 0.0010171812497404703,  relative_errX = 0.0014385487392419996
#          Target_Error = 1.4152031014668338
#
#      convergence check   -->  time = 0.00024700164794921875
#
#       stepRGD            -->  time = 0.0014069080352783203
#
#  --------  12-th iteration
#
#  12-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00016498565673828125
#        [calc_n1_n2] AptGk     -->  time = 4.291534423828125e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.002845720339253649
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00134316e+00 1.01090772e-06]
#         max(s2r)  = 1.0013431598496478
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.2369771136888851e-15
#             min(uk +/- uk_old)   = 0.0010047641348827085
#
#          relative_errU = 0.0010047641348827096,  relative_errX = 0.0014210293052416335
#          Target_Error = 1.4151957609264405
#
#      convergence check   -->  time = 8.20159912109375e-05
#
#       stepRGD            -->  time = 0.0005080699920654297
#
#  --------  13-th iteration
#
#  13-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.0001552104949951172
#        [calc_n1_n2] AptGk     -->  time = 3.695487976074219e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.0028331318821521786
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00133490e+00 1.00199198e-06]
#         max(s2r)  = 1.0013348971776517
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.147769759809152e-15
#             min(uk +/- uk_old)   = 0.0010003276724760764
#
#          relative_errU = 0.0010003276724760773,  relative_errX = 0.0014146950126137738
#          Target_Error = 1.415185982745458
#
#      convergence check   -->  time = 7.605552673339844e-05
#
#       stepRGD            -->  time = 0.0004832744598388672
#
#  --------  14-th iteration
#
#  14-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 0
#  np.allclose( Col_flip_sign(Gu), Col_flip_sign(Gv) ) = True
#        calc_PtG_2_uG_Gv       -->  time = 0.00015687942504882812
#        [calc_n1_n2] AptGk     -->  time = 3.600120544433594e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 0
#           D2s - D2s.T.conj() = 0.0027845181838777443
#           np.allclose(D2s, D2s.T.conj()) = False
#
#         s2r       = [1.00132329e+00 9.67911866e-07]
#         max(s2r)  = 1.00132328538312
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 0
#          error of Hermitian = LA.norm(|uk| - |vk|) = 1.009246962835748e-15
#             min(uk +/- uk_old)   = 0.0009831744678165332
#
#  *********  XkErrRatio = 0.0013904587936807765 < StpTol   ******
#          relative_errU = 0.0009831744678165336,  relative_errX = 0.0013904587936807765
#          Target_Error = 1.4151816951382719
#
#      convergence check   -->  time = 7.891654968261719e-05
#
#       stepRGD            -->  time = 0.0004780292510986328
#
#    RGD -->  Fname = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2-RGD_Ix1_Tr0_Ap0_sg0
#   RGD: worker container saved in Fname done = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2-RGD_Ix1_Tr0_Ap0_sg0_wrapper.dat
#
#    RGD method = RGD1
# The total time for ALL is [('RGD', 1, 0, 0.017625093460083008)]
#
#
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#  ++           start calculating  RGD                 ++
#  ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#   self.Noise = shot
#   Pj_method  = 1
#   mea_method = 1
#   --> loading measurement_list DONE from  ml_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/measureL_ALL.pickle
#
# Loading projectors
#    20 projectors loaded
#    Projectors ready to compute with
#
#
#   ******  projectors  -->  time = 0.0022420883178710938   ******
#
#    ===>  to GET measurment_list
#
# Loading measurements
#    Measurements ready to compute with
#
#    **** Loading measurements   -->   time = 1.0967254638671875e-05  ****
#
#   self.coef = 0.6324555320336759
#   InitX     = 0
#
#  ******  initial choice same as the MiFGD  *****
#
# self.seed = 0
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#  --------  X0  --> (-1)-th iteration  [ InitX = 0, SVD choice = -1 ]
#
#       X0 step (RGD)        -->  time = 0.0007028579711914062
#
#       X0                   -->  Tr(X0)     = (0.9999999999999999+0j)
#
#       X0                   -->  Target Err = 1.3498545053762772
#
#     RGD max num_iterations = 150
#
#  --------  0-th iteration
#
#  0-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 0.0017790794372558594
#        [calc_n1_n2] AptGk     -->  time = 0.0008027553558349609
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 0.0
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [0.60030034 0.27348661]
#         max(s2r)  = 0.6003003385653891
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#    ****  0-th iteratation
#
#             min(uk +/- uk_old)   = 0.5850459102937965
#
#          relative_errU = 0.5850459102937965,  relative_errX = 0.7318031633067206
#          Target_Error = 0.9742027858932396
#
#      convergence check   -->  time = 0.0002522468566894531
#
#       stepRGD            -->  time = 0.0034601688385009766
#
#  --------  1-th iteration
#
#  1-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 0.000209808349609375
#        [calc_n1_n2] AptGk     -->  time = 9.012222290039062e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 4.097583493753333e-17
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [0.68096139 0.26087432]
#         max(s2r)  = 0.6809613894669162
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.5471692355287904
#
#          relative_errU = 0.5471692355287904,  relative_errX = 0.8040275826953615
#          Target_Error = 0.6454613817691238
#
#      convergence check   -->  time = 0.00024509429931640625
#
#       stepRGD            -->  time = 0.0011761188507080078
#
#  --------  2-th iteration
#
#  2-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 0.00020313262939453125
#        [calc_n1_n2] AptGk     -->  time = 8.7738037109375e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 3.047251814081573e-17
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [0.82293161 0.11526947]
#         max(s2r)  = 0.8229316083576912
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.3562124604428923
#
#          relative_errU = 0.3562124604428923,  relative_errX = 0.5834554628640334
#          Target_Error = 0.3389750542901899
#
#      convergence check   -->  time = 9.083747863769531e-05
#
#       stepRGD            -->  time = 0.001055002212524414
#
#  --------  3-th iteration
#
#  3-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 8.606910705566406e-05
#        [calc_n1_n2] AptGk     -->  time = 4.220008850097656e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 2.0636179156666932e-17
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [0.94128209 0.03082639]
#         max(s2r)  = 0.9412820930335346
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.178791247615387
#
#          relative_errU = 0.178791247615387,  relative_errX = 0.3053288213322816
#          Target_Error = 0.15121395325654235
#
#      convergence check   -->  time = 8.58306884765625e-05
#
#       stepRGD            -->  time = 0.00044274330139160156
#
#  --------  4-th iteration
#
#  4-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.486343383789062e-05
#        [calc_n1_n2] AptGk     -->  time = 3.600120544433594e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 2.5956699710806805e-18
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [0.97641284 0.0042813 ]
#         max(s2r)  = 0.976412840805292
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.06610864767270554
#
#          relative_errU = 0.06610864767270554,  relative_errX = 0.10222510345246665
#          Target_Error = 0.07680899422666117
#
#      convergence check   -->  time = 8.296966552734375e-05
#
#       stepRGD            -->  time = 0.00039196014404296875
#
#  --------  5-th iteration
#
#  5-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.390975952148438e-05
#        [calc_n1_n2] AptGk     -->  time = 3.6716461181640625e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 7.599608445783214e-19
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [9.93989286e-01 6.32203892e-04]
#         max(s2r)  = 0.9939892862769748
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.025213560456707848
#
#          relative_errU = 0.025213560456707848,  relative_errX = 0.04022643810866139
#          Target_Error = 0.06093988765014329
#
#      convergence check   -->  time = 8.20159912109375e-05
#
#       stepRGD            -->  time = 0.00039505958557128906
#
#  --------  6-th iteration
#
#  6-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.414817810058594e-05
#        [calc_n1_n2] AptGk     -->  time = 3.5762786865234375e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 3.378416514639591e-19
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [9.98705373e-01 7.57671085e-05]
#         max(s2r)  = 0.9987053733758726
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.008709822582000256
#
#          relative_errU = 0.008709822582000256,  relative_errX = 0.01322687683545327
#          Target_Error = 0.05415264215844166
#
#      convergence check   -->  time = 7.390975952148438e-05
#
#       stepRGD            -->  time = 0.0003867149353027344
#
#  --------  7-th iteration
#
#  7-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.414817810058594e-05
#        [calc_n1_n2] AptGk     -->  time = 3.600120544433594e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 5.829311979461989e-19
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [1.00079619e+00 1.01882108e-05]
#         max(s2r)  = 1.000796193526782
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.003190615570506867
#
#          relative_errU = 0.003190615570506867,  relative_errX = 0.004978503573072618
#          Target_Error = 0.05376422182327288
#
#      convergence check   -->  time = 8.20159912109375e-05
#
#       stepRGD            -->  time = 0.0003809928894042969
#
#  --------  8-th iteration
#
#  8-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.295608520507812e-05
#        [calc_n1_n2] AptGk     -->  time = 3.600120544433594e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 1.2887441902372816e-19
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [1.00132539e+00 1.23553910e-06]
#         max(s2r)  = 1.001325389560529
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.0011108116650161795
#
#          relative_errU = 0.0011108116650161792,  relative_errX = 0.0016579240908340053
#          Target_Error = 0.05321786092163492
#
#      convergence check   -->  time = 7.82012939453125e-05
#
#       stepRGD            -->  time = 0.00037407875061035156
#
#  --------  9-th iteration
#
#  9-th step -> self.Remain_Hermitian = 1, self.EigV_positive = 1
#        calc_PtG_2_uG_Gv       -->  time = 7.295608520507812e-05
#        [calc_n1_n2] AptGk     -->  time = 4.291534423828125e-05
#
#     ************  0-th scaling for the Alpha
#     Hr_tangentWk  -->  Remain_Hermitian = 1, EigV_positve = 1
#           D2s - D2s.T.conj() = 2.304312885371635e-18
#           np.allclose(D2s, D2s.T.conj()) = True
#
#         s2r       = [1.00159188e+00 2.72300558e-07]
#         max(s2r)  = 1.0015918781192583
#     ------------  DONE svd of D2s with 0-th scaling (#max sc=1)
#             Hermitian ?    Remain_Hermiain = 1,    EigV_postive = 1
#          error of Hermitian = LA.norm(|uk| - |vk|) = 0.0
#             min(uk +/- uk_old)   = 0.0005214093611242347
#
#  *********  XkErrRatio = 0.0007840334123267357 < StpTol   ******
#          relative_errU = 0.0005214093611242347,  relative_errX = 0.0007840334123267357
#          Target_Error = 0.05336927245859004
#
#      convergence check   -->  time = 7.677078247070312e-05
#
#       stepRGD            -->  time = 0.0003809928894042969
#
#    RGD -->  Fname = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2-RGD_Ix0_Tr0_Ap0_sg0
#   RGD: worker container saved in Fname done = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2-RGD_Ix0_Tr0_Ap0_sg0_wrapper.dat
#
#    RGD method = RGD0
# The total time for ALL is [('RGD', 1, 0, 0.017625093460083008), ('RGD', 0, 0, 0.011693000793457031)]
#
#  ----------------  0-th mu = 4.5e-05   start ------------------
#
#
#
#  ******************************************************
#  **      start calculating MiFGD with mu = 4.5e-05     **
#  ******************************************************
#
#   self.Noise = shot
#   Pj_method  = 1
#   mea_method = 1
#   --> loading measurement_list DONE from  ml_file = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2_Measure/measureL_ALL.pickle
#
# Loading projectors
#    20 projectors loaded
#    Projectors ready to compute with
#
#
#   ******  projectors  -->  time = 0.00011491775512695312   ******
#
#    ===>  to GET measurment_list
#
# Loading measurements
#    Measurements ready to compute with
#
#    **** Loading measurements   -->   time = 1.0967254638671875e-05  ****
#
#  --------  X0  --> (-1)-th iteration  [ InitX = 1 ]
#
#       X0 step (MiFGD)      -->  time = 0.005870819091796875
#
#       X0                   -->  Tr(X0)     = (1.8414037232054983+9.347088897367744e-18j)
#
#       X0                   -->  Target Err = 1.591243494448885
#
#     MiFGD num_iterations = 150
#
#  --------  0-th iteration
#
# 0
#          relative_errU = 0.263089305801824,  relative_errX = 0.4569513478446291
#          Target_Error = 0.9937805100491082
#
#     projection_diff()  -->  time = 0.00011277198791503906
#     update variabels   -->  time = 9.059906005859375e-06
#     calc  Xk           -->  time = 1.2159347534179688e-05
#     convergence_check  -->  time = 0.0001399517059326172
#     step (MiFGD)       -->  time = 0.0002739429473876953
#
#  --------  1-th iteration
#
#          relative_errU = 0.06698166908829166,  relative_errX = 0.12945939964044162
#          Target_Error = 0.9353538795591025
#
#     projection_diff()  -->  time = 0.0001049041748046875
#     update variabels   -->  time = 7.867813110351562e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 9.489059448242188e-05
#     step (MiFGD)       -->  time = 0.000209808349609375
#
#  --------  2-th iteration
#
#          relative_errU = 0.04939517566353517,  relative_errX = 0.09633319286964015
#          Target_Error = 0.9052770488526695
#
#     projection_diff()  -->  time = 0.00010085105895996094
#     update variabels   -->  time = 7.152557373046875e-06
#     calc  Xk           -->  time = 1.6689300537109375e-06
#     convergence_check  -->  time = 8.916854858398438e-05
#     step (MiFGD)       -->  time = 0.00019884109497070312
#
#  --------  3-th iteration
#
#          relative_errU = 0.03800890686290958,  relative_errX = 0.07455487570270793
#          Target_Error = 0.8882226214833657
#
#     projection_diff()  -->  time = 0.00010085105895996094
#     update variabels   -->  time = 1.4066696166992188e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.987022399902344e-05
#     step (MiFGD)       -->  time = 0.00019693374633789062
#
#  --------  4-th iteration
#
#          relative_errU = 0.030047208371756593,  relative_errX = 0.059171064310428415
#          Target_Error = 0.8778559942558656
#
#     projection_diff()  -->  time = 0.00010013580322265625
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 7.724761962890625e-05
#     step (MiFGD)       -->  time = 0.0001862049102783203
#
#  --------  5-th iteration
#
#          relative_errU = 0.02420142934000393,  relative_errX = 0.04779288196900195
#          Target_Error = 0.8711920411258494
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00017786026000976562
#
#  --------  6-th iteration
#
#          relative_errU = 0.019761718428014264,  relative_errX = 0.03910308833424788
#          Target_Error = 0.8666909318124331
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 7.796287536621094e-05
#     step (MiFGD)       -->  time = 0.00017881393432617188
#
#  --------  7-th iteration
#
#          relative_errU = 0.016306228046843892,  relative_errX = 0.032308945334161
#          Target_Error = 0.8635029571206128
#
#     projection_diff()  -->  time = 0.00010013580322265625
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 7.867813110351562e-06
#     convergence_check  -->  time = 7.295608520507812e-05
#     step (MiFGD)       -->  time = 0.00018787384033203125
#
#  --------  8-th iteration
#
#          relative_errU = 0.013567212124358614,  relative_errX = 0.026902113485164893
#          Target_Error = 0.8611338673927785
#
#     projection_diff()  -->  time = 9.274482727050781e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.295608520507812e-05
#     step (MiFGD)       -->  time = 0.00017380714416503906
#
#  --------  9-th iteration
#
#          relative_errU = 0.011366101300278557,  relative_errX = 0.022540531174183163
#          Target_Error = 0.8592836491310707
#
#     projection_diff()  -->  time = 9.322166442871094e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.891654968261719e-05
#     step (MiFGD)       -->  time = 0.0001800060272216797
#
#  --------  10-th iteration
#
#          relative_errU = 0.009579174682779721,  relative_errX = 0.01898520888335631
#          Target_Error = 0.8577635766642925
#
#     projection_diff()  -->  time = 9.417533874511719e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.82012939453125e-05
#     step (MiFGD)       -->  time = 0.00017905235290527344
#
#  --------  11-th iteration
#
#          relative_errU = 0.008118162820154916,  relative_errX = 0.016064148463302907
#          Target_Error = 0.8564511963624317
#
#     projection_diff()  -->  time = 9.989738464355469e-05
#     update variabels   -->  time = 1.3113021850585938e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.081031799316406e-05
#     step (MiFGD)       -->  time = 0.00018596649169921875
#
#  --------  12-th iteration
#
#          relative_errU = 0.006918695328649152,  relative_errX = 0.013650664434571146
#          Target_Error = 0.8552647913479828
#
#     projection_diff()  -->  time = 0.00011801719665527344
#     update variabels   -->  time = 8.344650268554688e-06
#     calc  Xk           -->  time = 1.6689300537109375e-06
#     convergence_check  -->  time = 0.00011801719665527344
#     step (MiFGD)       -->  time = 0.0002460479736328125
#
#  --------  13-th iteration
#
#          relative_errU = 0.005933114176597477,  relative_errX = 0.011649808700784733
#          Target_Error = 0.8541483460695414
#
#     projection_diff()  -->  time = 0.00010800361633300781
#     update variabels   -->  time = 9.059906005859375e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 0.0001251697540283203
#     step (MiFGD)       -->  time = 0.00024437904357910156
#
#  --------  14-th iteration
#
#          relative_errU = 0.005125818587381551,  relative_errX = 0.009989572622915274
#          Target_Error = 0.8530624066394963
#
#     projection_diff()  -->  time = 0.00010609626770019531
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 9.107589721679688e-05
#     step (MiFGD)       -->  time = 0.00020599365234375
#
#  --------  15-th iteration
#
#          relative_errU = 0.004470102411490843,  relative_errX = 0.00861500398356634
#          Target_Error = 0.8519783697924793
#
#     projection_diff()  -->  time = 9.5367431640625e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 7.987022399902344e-05
#     step (MiFGD)       -->  time = 0.00018310546875
#
#  --------  16-th iteration
#
#          relative_errU = 0.003945845998085625,  relative_errX = 0.0074841268203144256
#          Target_Error = 0.8508748270207153
#
#     projection_diff()  -->  time = 9.489059448242188e-05
#     update variabels   -->  time = 7.152557373046875e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.796287536621094e-05
#     step (MiFGD)       -->  time = 0.00018095970153808594
#
#  --------  17-th iteration
#
#          relative_errU = 0.00353764743754633,  relative_errX = 0.006564942489007593
#          Target_Error = 0.8497351734563331
#
#     projection_diff()  -->  time = 0.00012302398681640625
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 8.106231689453125e-05
#     step (MiFGD)       -->  time = 0.00021219253540039062
#
#  --------  18-th iteration
#
#          relative_errU = 0.0032331507380355014,  relative_errX = 0.005832998294240097
#          Target_Error = 0.8485460131161531
#
#     projection_diff()  -->  time = 9.608268737792969e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 7.200241088867188e-05
#     step (MiFGD)       -->  time = 0.00017499923706054688
#
#  --------  19-th iteration
#
#          relative_errU = 0.003021530560421466,  relative_errX = 0.00526915597273947
#          Target_Error = 0.8472960756895734
#
#     projection_diff()  -->  time = 9.179115295410156e-05
#     update variabels   -->  time = 1.3113021850585938e-05
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 6.794929504394531e-05
#     step (MiFGD)       -->  time = 0.0001747608184814453
#
#  --------  20-th iteration
#
#          relative_errU = 0.0028923131988319688,  relative_errX = 0.004857386140258668
#          Target_Error = 0.845975467641456
#
#     projection_diff()  -->  time = 9.274482727050781e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 9.059906005859375e-06
#     convergence_check  -->  time = 6.985664367675781e-05
#     step (MiFGD)       -->  time = 0.00017786026000976562
#
#  --------  21-th iteration
#
#          relative_errU = 0.002834809370644451,  relative_errX = 0.004582718818893489
#          Target_Error = 0.8445751450550198
#
#     projection_diff()  -->  time = 9.322166442871094e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.700920104980469e-05
#     step (MiFGD)       -->  time = 0.00017714500427246094
#
#  --------  22-th iteration
#
#          relative_errU = 0.0028382614249204377,  relative_errX = 0.004429788312436616
#          Target_Error = 0.8430865353700959
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 8.702278137207031e-05
#     step (MiFGD)       -->  time = 0.00018787384033203125
#
#  --------  23-th iteration
#
#          relative_errU = 0.0028924687474331293,  relative_errX = 0.004382427446743563
#          Target_Error = 0.8415012600844011
#
#     projection_diff()  -->  time = 9.989738464355469e-05
#     update variabels   -->  time = 1.3828277587890625e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 6.914138793945312e-05
#     step (MiFGD)       -->  time = 0.0001850128173828125
#
#  --------  24-th iteration
#
#          relative_errU = 0.0029884660666085177,  relative_errX = 0.004424332036432771
#          Target_Error = 0.8398109263939454
#
#     projection_diff()  -->  time = 9.107589721679688e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.914138793945312e-05
#     step (MiFGD)       -->  time = 0.00016808509826660156
#
#  --------  25-th iteration
#
#          relative_errU = 0.0031189387702717838,  relative_errX = 0.00454026434519104
#          Target_Error = 0.8380069660769793
#
#     projection_diff()  -->  time = 9.179115295410156e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 7.152557373046875e-07
#     convergence_check  -->  time = 6.914138793945312e-05
#     step (MiFGD)       -->  time = 0.0001678466796875
#
#  --------  26-th iteration
#
#          relative_errU = 0.0032783032634629357,  relative_errX = 0.004717110022270939
#          Target_Error = 0.8360805067334369
#
#     projection_diff()  -->  time = 9.179115295410156e-05
#     update variabels   -->  time = 1.3113021850585938e-05
#     calc  Xk           -->  time = 8.821487426757812e-06
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00018978118896484375
#
#  --------  27-th iteration
#
#          relative_errU = 0.0034625467070673543,  relative_errX = 0.004944404902837539
#          Target_Error = 0.8340222650419059
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00017690658569335938
#
#  --------  28-th iteration
#
#          relative_errU = 0.0036689568124373805,  relative_errX = 0.005214336859624065
#          Target_Error = 0.8318224547777712
#
#     projection_diff()  -->  time = 9.965896606445312e-05
#     update variabels   -->  time = 7.152557373046875e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 6.771087646484375e-05
#     step (MiFGD)       -->  time = 0.00017571449279785156
#
#  --------  29-th iteration
#
#          relative_errU = 0.003895836987424693,  relative_errX = 0.005521423478112461
#          Target_Error = 0.8294707044508455
#
#     projection_diff()  -->  time = 0.00010013580322265625
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 7.700920104980469e-05
#     step (MiFGD)       -->  time = 0.00018525123596191406
#
#  --------  30-th iteration
#
#          relative_errU = 0.004142255253102223,  relative_errX = 0.0058620692179392215
#          Target_Error = 0.8269559808924769
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 1.6689300537109375e-06
#     convergence_check  -->  time = 6.914138793945312e-05
#     step (MiFGD)       -->  time = 0.00016999244689941406
#
#  --------  31-th iteration
#
#          relative_errU = 0.004407842363370575,  relative_errX = 0.006234131031839225
#          Target_Error = 0.8242665161637356
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 8.821487426757812e-06
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00018405914306640625
#
#  --------  32-th iteration
#
#          relative_errU = 0.0046926374590743215,  relative_errX = 0.0066365497913982606
#          Target_Error = 0.8213897359101925
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 7.009506225585938e-05
#     step (MiFGD)       -->  time = 0.0001709461212158203
#
#  --------  33-th iteration
#
#          relative_errU = 0.004996973009495304,  relative_errX = 0.0070690606021732725
#          Target_Error = 0.8183121878523296
#
#     projection_diff()  -->  time = 9.202957153320312e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.059906005859375e-06
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00018310546875
#
#  --------  34-th iteration
#
#          relative_errU = 0.00532138960298997,  relative_errX = 0.007531974392413492
#          Target_Error = 0.8150194695419146
#
#     projection_diff()  -->  time = 0.00010013580322265625
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.818771362304688e-05
#     step (MiFGD)       -->  time = 0.0001761913299560547
#
#  --------  35-th iteration
#
# ...
#     step (MiFGD)       -->  time = 0.000988006591796875
#
#  --------  31-th iteration
#
#          relative_errU = 0.020523413171697386,  relative_errX = 0.03238339753875436
#          Target_Error = 0.3272424467863202
#
#     projection_diff()  -->  time = 0.0003046989440917969
#     update variabels   -->  time = 1.7881393432617188e-05
#     calc  Xk           -->  time = 1.3113021850585938e-05
#     convergence_check  -->  time = 0.00019621849060058594
#     step (MiFGD)       -->  time = 0.0005319118499755859
#
#  --------  32-th iteration
#
#          relative_errU = 0.01924353996343601,  relative_errX = 0.030311717192968737
#          Target_Error = 0.30403079728726373
#
#     projection_diff()  -->  time = 0.00015091896057128906
#     update variabels   -->  time = 1.621246337890625e-05
#     calc  Xk           -->  time = 9.059906005859375e-06
#     convergence_check  -->  time = 0.000110626220703125
#     step (MiFGD)       -->  time = 0.0002868175506591797
#
#  --------  33-th iteration
#
#          relative_errU = 0.01795080096880151,  relative_errX = 0.02821562685381482
#          Target_Error = 0.2820477503092545
#
#     projection_diff()  -->  time = 0.00010180473327636719
#     update variabels   -->  time = 1.4066696166992188e-05
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 8.296966552734375e-05
#     step (MiFGD)       -->  time = 0.00020074844360351562
#
#  --------  34-th iteration
#
#          relative_errU = 0.016664164397743465,  relative_errX = 0.02612665696279646
#          Target_Error = 0.2613755374357472
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.200241088867188e-05
#     step (MiFGD)       -->  time = 0.00017309188842773438
#
#  --------  35-th iteration
#
#          relative_errU = 0.015401395960509087,  relative_errX = 0.024074814044615308
#          Target_Error = 0.24206516626813568
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.009506225585938e-05
#     step (MiFGD)       -->  time = 0.00016999244689941406
#
#  --------  36-th iteration
#
#          relative_errU = 0.014178080632484146,  relative_errX = 0.022086785972613973
#          Target_Error = 0.22413756224234105
#
#     projection_diff()  -->  time = 0.00010013580322265625
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.700920104980469e-05
#     step (MiFGD)       -->  time = 0.0001850128173828125
#
#  --------  37-th iteration
#
#          relative_errU = 0.013006996751736577,  relative_errX = 0.020184727954653117
#          Target_Error = 0.20758637524486853
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 7.867813110351562e-06
#     convergence_check  -->  time = 7.128715515136719e-05
#     step (MiFGD)       -->  time = 0.0001780986785888672
#
#  --------  38-th iteration
#
#          relative_errU = 0.011897830228474642,  relative_errX = 0.01838563675090874
#          Target_Error = 0.19238195047830997
#
#     projection_diff()  -->  time = 9.489059448242188e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 7.152557373046875e-07
#     convergence_check  -->  time = 7.510185241699219e-05
#     step (MiFGD)       -->  time = 0.00017690658569335938
#
#  --------  39-th iteration
#
#          relative_errU = 0.010857180741930558,  relative_errX = 0.016701248391114313
#          Target_Error = 0.17847592615256105
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.890296936035156e-05
#     step (MiFGD)       -->  time = 0.00016880035400390625
#
#  --------  40-th iteration
#
#          relative_errU = 0.009888790640927481,  relative_errX = 0.015138348772759352
#          Target_Error = 0.1658059647594096
#
#     projection_diff()  -->  time = 9.5367431640625e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 6.985664367675781e-05
#     step (MiFGD)       -->  time = 0.00017213821411132812
#
#  --------  41-th iteration
#
#          relative_errU = 0.008993920603846017,  relative_errX = 0.013699367830962064
#          Target_Error = 0.15430022389326986
#
#     projection_diff()  -->  time = 9.799003601074219e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.985664367675781e-05
#     step (MiFGD)       -->  time = 0.00017571449279785156
#
#  --------  42-th iteration
#
#          relative_errU = 0.008171801074466982,  relative_errX = 0.0123831318294733
#          Target_Error = 0.14388129698879562
#
#     projection_diff()  -->  time = 9.918212890625e-05
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 6.794929504394531e-05
#     step (MiFGD)       -->  time = 0.00017499923706054688
#
#  --------  43-th iteration
#
#          relative_errU = 0.00742010092425203,  relative_errX = 0.011185667285525667
#          Target_Error = 0.1344694779632725
#
#     projection_diff()  -->  time = 9.274482727050781e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 8.106231689453125e-06
#     convergence_check  -->  time = 6.699562072753906e-05
#     step (MiFGD)       -->  time = 0.00017380714416503906
#
#  --------  44-th iteration
#
#          relative_errU = 0.006735370544069504,  relative_errX = 0.010100976388171246
#          Target_Error = 0.1259853086927152
#
#     projection_diff()  -->  time = 9.322166442871094e-05
#     update variabels   -->  time = 4.76837158203125e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 6.699562072753906e-05
#     step (MiFGD)       -->  time = 0.0001671314239501953
#
#  --------  45-th iteration
#
#          relative_errU = 0.006113432314899924,  relative_errX = 0.00912173119287849
#          Target_Error = 0.11835144564269401
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.723403930664062e-05
#     step (MiFGD)       -->  time = 0.0001671314239501953
#
#  --------  46-th iteration
#
#          relative_errU = 0.005549704996442557,  relative_errX = 0.008239858192958853
#          Target_Error = 0.11149393048291256
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 5.9604644775390625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.295608520507812e-05
#     step (MiFGD)       -->  time = 0.00017380714416503906
#
#  --------  47-th iteration
#
#          relative_errU = 0.005039458981138106,  relative_errX = 0.007447003976563631
#          Target_Error = 0.10534297278357536
#
#     projection_diff()  -->  time = 9.202957153320312e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 6.985664367675781e-05
#     step (MiFGD)       -->  time = 0.00016999244689941406
#
#  --------  48-th iteration
#
#          relative_errU = 0.004578006431595103,  relative_errX = 0.006734886080474954
#          Target_Error = 0.09983335697090594
#
#     projection_diff()  -->  time = 9.179115295410156e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.390975952148438e-05
#     step (MiFGD)       -->  time = 0.00017404556274414062
#
#  --------  49-th iteration
#
#          relative_errU = 0.004160834437373872,  relative_errX = 0.0060955413721716515
#          Target_Error = 0.09490457707739272
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 1.1920928955078125e-05
#     calc  Xk           -->  time = 7.867813110351562e-06
#     convergence_check  -->  time = 6.723403930664062e-05
#     step (MiFGD)       -->  time = 0.0001800060272216797
#
#  --------  50-th iteration
#
#          relative_errU = 0.0037836911342708965,  relative_errX = 0.005521488352578968
#          Target_Error = 0.09050078713782167
#
#     projection_diff()  -->  time = 9.799003601074219e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 7.486343383789062e-05
#     step (MiFGD)       -->  time = 0.00018095970153808594
#
#  --------  51-th iteration
#
#          relative_errU = 0.0034426349162665765,  relative_errX = 0.0050058208227849715
#          Target_Error = 0.08657063671436563
#
#     projection_diff()  -->  time = 0.00011229515075683594
#     update variabels   -->  time = 5.7220458984375e-06
#     calc  Xk           -->  time = 1.1920928955078125e-06
#     convergence_check  -->  time = 6.985664367675781e-05
#     step (MiFGD)       -->  time = 0.00018906593322753906
#
#  --------  52-th iteration
#
#          relative_errU = 0.003134056053053457,  relative_errX = 0.00454224945208139
#          Target_Error = 0.08306704296196542
#
#     projection_diff()  -->  time = 9.822845458984375e-05
#     update variabels   -->  time = 6.9141387939453125e-06
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 6.914138793945312e-05
#     step (MiFGD)       -->  time = 0.0001761913299560547
#
#  --------  53-th iteration
#
#          relative_errU = 0.002854678689882808,  relative_errX = 0.004125105775638488
#          Target_Error = 0.07994693465602105
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 1.1920928955078125e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.605552673339844e-05
#     step (MiFGD)       -->  time = 0.00018405914306640625
#
#  --------  54-th iteration
#
#          relative_errU = 0.0026015496960043803,  relative_errX = 0.003749320666700474
#          Target_Error = 0.07717099056958486
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 7.581710815429688e-05
#     step (MiFGD)       -->  time = 0.00017690658569335938
#
#  --------  55-th iteration
#
#          relative_errU = 0.002372019362951064,  relative_errX = 0.0034103867928906
#          Target_Error = 0.07470338473319538
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 1.0967254638671875e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 6.67572021484375e-05
#     step (MiFGD)       -->  time = 0.0001728534698486328
#
#  --------  56-th iteration
#
#          relative_errU = 0.0021637176559095605,  relative_errX = 0.0031043122334134415
#          Target_Error = 0.07251154424369893
#
#     projection_diff()  -->  time = 9.298324584960938e-05
#     update variabels   -->  time = 1.1920928955078125e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.295608520507812e-05
#     step (MiFGD)       -->  time = 0.0001800060272216797
#
#  --------  57-th iteration
#
#          relative_errU = 0.0019745286421493486,  relative_errX = 0.0028275704325890516
#          Target_Error = 0.07056592096988742
#
#     projection_diff()  -->  time = 9.393692016601562e-05
#     update variabels   -->  time = 6.198883056640625e-06
#     calc  Xk           -->  time = 9.5367431640625e-07
#     convergence_check  -->  time = 6.794929504394531e-05
#     step (MiFGD)       -->  time = 0.0001690387725830078
#
#  --------  58-th iteration
#
#          relative_errU = 0.0018025648666738904,  relative_errX = 0.0025770500380114534
#          Target_Error = 0.06883977617932215
#
#     projection_diff()  -->  time = 9.179115295410156e-05
#     update variabels   -->  time = 1.3113021850585938e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 7.009506225585938e-05
#     step (MiFGD)       -->  time = 0.00017714500427246094
#
#  --------  59-th iteration
#
#          relative_errU = 0.0016461427979137934,  relative_errX = 0.0023500069074955388
#          Target_Error = 0.06730897621183292
#
#     projection_diff()  -->  time = 9.226799011230469e-05
#     update variabels   -->  time = 1.0967254638671875e-05
#     calc  Xk           -->  time = 2.1457672119140625e-06
#     convergence_check  -->  time = 0.0009367465972900391
#     step (MiFGD)       -->  time = 0.0010421276092529297
#
#  --------  60-th iteration
#
#          relative_errU = 0.0015037599943619265,  relative_errX = 0.00214401962698184
#          Target_Error = 0.06595179733131941
#
#     projection_diff()  -->  time = 0.0003750324249267578
#     update variabels   -->  time = 2.09808349609375e-05
#     calc  Xk           -->  time = 5.9604644775390625e-06
#     convergence_check  -->  time = 0.00023412704467773438
#     step (MiFGD)       -->  time = 0.0006361007690429688
#
#  --------  61-th iteration
#
#          relative_errU = 0.0013740743122683332,  relative_errX = 0.001956949208159894
#          Target_Error = 0.06474873837214681
#
#     projection_diff()  -->  time = 0.00025725364685058594
#     update variabels   -->  time = 1.3589859008789062e-05
#     calc  Xk           -->  time = 1.1205673217773438e-05
#     convergence_check  -->  time = 0.00018095970153808594
#     step (MiFGD)       -->  time = 0.0004630088806152344
#
#  --------  62-th iteration
#
#          relative_errU = 0.0012486165379378394,  relative_errX = 0.0017664072235986873
#          Target_Error = 0.06367521734808389
#
#     projection_diff()  -->  time = 0.00025391578674316406
#     update variabels   -->  time = 2.4080276489257812e-05
#     calc  Xk           -->  time = 4.0531158447265625e-06
#     convergence_check  -->  time = 0.00017380714416503906
#     step (MiFGD)       -->  time = 0.0004558563232421875
#
#  --------  63-th iteration
#
#          relative_errU = 0.0011419996182105716,  relative_errX = 0.0016150310850152215
#          Target_Error = 0.06272102378135702
#
#     projection_diff()  -->  time = 0.0002598762512207031
#     update variabels   -->  time = 1.621246337890625e-05
#     calc  Xk           -->  time = 4.0531158447265625e-06
#     convergence_check  -->  time = 0.0001609325408935547
#     step (MiFGD)       -->  time = 0.0004410743713378906
#
#  --------  64-th iteration
#
#          relative_errU = 0.0010449186318600202,  relative_errX = 0.0014777378990683107
#          Target_Error = 0.06187427629479907
#
#     projection_diff()  -->  time = 0.0002930164337158203
#     update variabels   -->  time = 0.00013303756713867188
#     calc  Xk           -->  time = 2.86102294921875e-06
#     convergence_check  -->  time = 0.000102996826171875
#     step (MiFGD)       -->  time = 0.0005319118499755859
#
#  --------  65-th iteration
#
#          relative_errU = 0.0009561706233616585,  relative_errX = 0.0013522293089642385
#          Target_Error = 0.06112267211395244
#
#     projection_diff()  -->  time = 0.00010371208190917969
#     update variabels   -->  time = 1.430511474609375e-05
#     calc  Xk           -->  time = 1.9073486328125e-06
#     convergence_check  -->  time = 7.390975952148438e-05
#     step (MiFGD)       -->  time = 0.0001938343048095703
#
#   MiFGD: worker container saved in Fname done = ./DataTest/GHZ-3/GHZ-3_m20_s1/GHZ-3_m20_s1_shot2400_v2-MiFGD-mu4.5e-05-eT2_wrapper.dat
#
# The total time for each mu is [('RGD', 1, 0, 0.017625093460083008), ('RGD', 0, 0, 0.011693000793457031), (4.5e-05, 1, 2, 0.027143001556396484), (4.5e-05, 0, 2, 0.01931476593017578)]

# %% [markdown]
# ### Run various Kappa cases for StateName == 'KapRnd'
# - List_alpha: parameters of different Kappa for StateName == 'KapRnd' only

# %%
if params_setup['StateName'] == 'KapRnd':
    T_Rho, Wk_Rho = Tune_Kappa_Tomography(params_setup, target_density_matrix, \
            input_S, T_rec, Ncpu_Pj, pm_MiFGD, pm_RGD)
